# %%
# 운영 체제마다 한글이 보이게 하는 설정
# 윈도우
import platform
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# '-' 기호 보이게 하기
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Windows':
    path = "C:\\Windows\\Fonts\\malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spst

# %%
parent_child_activity = pd.read_csv('./부모님_또는_양육자_과의_활동.csv', encoding='ANSI')
parental_interest = pd.read_csv('./부모님_또는_양육자_의_관심.csv', encoding='ANSI')
mental_health = pd.read_csv('./우울감__자아존중감.csv', encoding='ANSI')

school_life_satisfaction = pd.read_csv('./학교생활_만족도.csv', encoding='ANSI')
academic_achievement = pd.read_csv('./학업_성취도.csv', encoding='ANSI')

# %%
display(parent_child_activity)
display(parental_interest)
display(mental_health)
display(school_life_satisfaction)
display(academic_achievement)
# Out:
#    특성별(1)        특성별(2)   나의 고민에 대한 대화 나의 고민에 대한 대화.1 나의 고민에 대한 대화.2  \
# 0  특성별(1)        특성별(2)  거의 하지 않는다 (%)     월 1~3회 (%)     주 1~3회 (%)
# 1      전체            소계           13.9           39.5           32.1
# 2   가구 형태  한부모 및 조손가족 등           18.2           35.3             32
#
#   나의 고민에 대한 대화.3 나의 고민에 대한 대화.4    학교생활에 대한 대화 학교생활에 대한 대화.1 학교생활에 대한 대화.2  \
# 0     주 4~6회 (%)      매일 한다 (%)  거의 하지 않는다 (%)    월 1~3회 (%)    주 1~3회 (%)
# 1           10.2            4.2            8.8          28.4          36.3
# 2           10.4            4.1            9.6          26.8          32.9
#
#    ...          여가 활동     여가 활동.1     여가 활동.2     여가 활동.3    여가 활동.4  \
# 0  ...  거의 하지 않는다 (%)  월 1~3회 (%)  주 1~3회 (%)  주 4~6회 (%)  매일 한다 (%)
# 1  ...           11.3        37.5        32.4        14.3        4.4
# 2  ...           21.1        33.1        27.9        12.8          5
#
#            저녁 식사     저녁 식사.1     저녁 식사.2     저녁 식사.3    저녁 식사.4
# 0  거의 하지 않는다 (%)  월 1~3회 (%)  주 1~3회 (%)  주 4~6회 (%)  매일 한다 (%)
# 1            3.2         9.3        31.2        30.2       26.1
# 2            2.2          12        38.3        24.9       22.5
#
# [3 rows x 33 columns]
#    특성별(1)        특성별(2) 학교 수업(학원 포함)이 끝난 후 집에 늦게 들어와도 관심이 없다  \
# 0  특성별(1)        특성별(2)                        전혀 그렇지 않다 (%)
# 1      전체            소계                                 70.3
# 2   가구 형태  한부모 및 조손가족 등                                 60.2
#
#   학교 수업(학원 포함)이 끝난 후 집에 늦게 들어와도 관심이 없다.1  \
# 0                         그렇지 않은 편이다 (%)
# 1                                   17.4
# 2                                     26
#
#   학교 수업(학원 포함)이 끝난 후 집에 늦게 들어와도 관심이 없다.2  \
# 0                             그런 편이다 (%)
# 1                                   11.3
# 2                                   12.8
#
#   학교 수업(학원 포함)이 끝난 후 집에 늦게 들어와도 관심이 없다.3  \
# 0                             매우 그렇다 (%)
# 1                                      1
# 2                                      1
#
#   학교 수업(학원 포함)이 끝난 후 집에 늦게 들어와도 관심이 없다.4 내가 고열이 나거나 아파도 그냥 내버려둔 적이 있다  \
# 0                                 평균 (점)                전혀 그렇지 않다 (%)
# 1                                   1.43                         77.1
# 2                                   1.55                         70.3
#
#   내가 고열이 나거나 아파도 그냥 내버려둔 적이 있다.1 내가 고열이 나거나 아파도 그냥 내버려둔 적이 있다.2  \
# 0                 그렇지 않은 편이다 (%)                     그런 편이다 (%)
# 1                           10.6                           11.4
# 2                           20.3                            7.9
#
#   내가 고열이 나거나 아파도 그냥 내버려둔 적이 있다.3 내가 고열이 나거나 아파도 그냥 내버려둔 적이 있다.4
# 0                     매우 그렇다 (%)                         평균 (점)
# 1                            0.9                           1.36
# 2                            1.6                           1.41
#    응답자유형별(1)  응답자유형별(2)              우울감            우울감.1            우울감.2  \
# 0  응답자유형별(1)  응답자유형별(2)  이유 없이 외로운 적이 있다  이유 없이 외로운 적이 있다  이유 없이 외로운 적이 있다
# 1  응답자유형별(1)  응답자유형별(2)        전혀 그렇지 않다       그렇지 않은 편이다           그런 편이다
# 2         전체         소계             39.5             25.9             27.5
# 3      가족유형별      한부모가정             30.9             23.6             35.5
# 4      가족유형별       조손가정             52.6             21.7             19.8
#
#              우울감.3            우울감.4            우울감.5            우울감.6  \
# 0  이유 없이 외로운 적이 있다  이유 없이 불안한 적이 있다  이유 없이 불안한 적이 있다  이유 없이 불안한 적이 있다
# 1           매우 그렇다        전혀 그렇지 않다       그렇지 않은 편이다           그런 편이다
# 2              7.2             43.3             25.2             24.3
# 3               10             34.7             27.7             27.8
# 4              5.9             50.4             19.4             26.7
#
#              우울감.7  ...           자아존중감.2           자아존중감.3  \
# 0  이유 없이 불안한 적이 있다  ...  가치 있는 사람이라고 생각한다  가치 있는 사람이라고 생각한다
# 1           매우 그렇다  ...            그런 편이다            매우 그렇다
# 2              7.2  ...              42.3              33.5
# 3              9.9  ...              47.2              25.8
# 4              3.5  ...              40.1              24.9
#
#                       자아존중감.4                     자아존중감.5  \
# 0  좋은 자질(장점)을 많이 가지고 있다고 생각한다  좋은 자질(장점)을 많이 가지고 있다고 생각한다
# 1                   전혀 그렇지 않다                  그렇지 않은 편이다
# 2                         7.2                        21.1
# 3                         8.8                        26.5
# 4                        12.7                         9.2
#
#                       자아존중감.6                     자아존중감.7  \
# 0  좋은 자질(장점)을 많이 가지고 있다고 생각한다  좋은 자질(장점)을 많이 가지고 있다고 생각한다
# 1                      그런 편이다                      매우 그렇다
# 2                        42.2                        29.5
# 3                        42.5                        22.2
# 4                        54.1                        24.1
#
#                         자아존중감.8                       자아존중감.9  \
# 0  나 스스로에 대해 자랑스러워할 만한 것이 별로 없다  나 스스로에 대해 자랑스러워할 만한 것이 별로 없다
# 1                     전혀 그렇지 않다                    그렇지 않은 편이다
# 2                          35.2                          34.6
# 3                          26.2                          34.9
# 4                          39.7                          27.7
#
#                        자아존중감.10                      자아존중감.11
# 0  나 스스로에 대해 자랑스러워할 만한 것이 별로 없다  나 스스로에 대해 자랑스러워할 만한 것이 별로 없다
# 1                        그런 편이다                        매우 그렇다
# 2                          25.5                           4.7
# 3                          31.2                           7.7
# 4                          26.8                           5.9
#
# [5 rows x 26 columns]
#    특성별(1)        특성별(2) 나는 수업 시간이 재미있다 나는 수업 시간이 재미있다.1 나는 수업 시간이 재미있다.2  \
# 0  특성별(1)        특성별(2)  전혀 그렇지 않다 (%)   그렇지 않은 편이다 (%)       그런 편이다 (%)
# 1      전체            소계            1.2               29             64.6
# 2   가구 형태  한부모 및 조손가족 등              3             35.2             59.5
#
#   나는 수업 시간이 재미있다.3 나는 수업 시간이 재미있다.4 우리 학교는 우리들의 의견을 잘 반영한다  \
# 0       매우 그렇다 (%)           평균 (점)          전혀 그렇지 않다 (%)
# 1              5.2             2.74                    1.3
# 2              2.3             2.61                      4
#
#   우리 학교는 우리들의 의견을 잘 반영한다.1 우리 학교는 우리들의 의견을 잘 반영한다.2  ... 우리 학교는 교칙이 엄격하다  \
# 0           그렇지 않은 편이다 (%)               그런 편이다 (%)  ...   전혀 그렇지 않다 (%)
# 1                     27.5                       58  ...             1.8
# 2                     27.9                     57.7  ...               3
#
#   우리 학교는 교칙이 엄격하다.1 우리 학교는 교칙이 엄격하다.2 우리 학교는 교칙이 엄격하다.3 우리 학교는 교칙이 엄격하다.4  \
# 0    그렇지 않은 편이다 (%)        그런 편이다 (%)        매우 그렇다 (%)            평균 (점)
# 1                37              49.1              12.2              2.72
# 2              35.2              50.9              10.8               2.7
#
#   선생님 친구 등과의 관계를 고려하면 현재 다니고 있는 학교의 생활이 만족스럽다  \
# 0                               전혀 그렇지 않다 (%)
# 1                                         0.6
# 2                                         2.1
#
#   선생님 친구 등과의 관계를 고려하면 현재 다니고 있는 학교의 생활이 만족스럽다.1  \
# 0                                그렇지 않은 편이다 (%)
# 1                                            20
# 2                                            29
#
#   선생님 친구 등과의 관계를 고려하면 현재 다니고 있는 학교의 생활이 만족스럽다.2  \
# 0                                    그런 편이다 (%)
# 1                                          74.2
# 2                                          65.3
#
#   선생님 친구 등과의 관계를 고려하면 현재 다니고 있는 학교의 생활이 만족스럽다.3  \
# 0                                    매우 그렇다 (%)
# 1                                           5.2
# 2                                           3.6
#
#   선생님 친구 등과의 관계를 고려하면 현재 다니고 있는 학교의 생활이 만족스럽다.4
# 0                                        평균 (점)
# 1                                          2.84
# 2                                          2.71
#
# [3 rows x 27 columns]
#   특성별(1)        특성별(2)  매우 못한다 (%)  못하는 편이다 (%)  보통이다 (%)  잘하는 편이다 (%)  \
# 0     전체            소계         0.8          8.0      51.2         38.2
# 1  가구 형태  한부모 및 조손가족 등         2.3         17.1      55.1         25.5
#
#    매우 잘한다 (%)  평균 (점)
# 0         1.9    3.32
# 1         0.0    3.04

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
file_path = './부모님_또는_양육자_과의_활동.csv'
data = pd.read_csv(file_path, encoding='cp949')

# "전체"와 "조손가정" 데이터 추출
overall_data = data[data['특성별(2)'].str.contains('소계', na=False)]
joson_data = data[data['특성별(2)'].str.contains('한부모 및 조손가족 등', na=False)]

# 특성 그룹 생성 (6개로 분류)
categories_groups = {
    "나의 고민에 대한 대화": ["거의 하지 않는다 (%)", "월 1~3회 (%)", "주 1~3회 (%)", "주 4~6회 (%)", "매일 한다 (%)"],
    "학교생활에 대한 대화": ["거의 하지 않는다 (%)", "월 1~3회 (%)", "주 1~3회 (%)", "주 4~6회 (%)", "매일 한다 (%)", "해당 없음 (%)"],
    "책 텔레비전 영화에 대한 대화": ["거의 하지 않는다 (%)", "월 1~3회 (%)", "주 1~3회 (%)", "주 4~6회 (%)", "매일 한다 (%)"],
    "정치 사회적 주제에 관한 대화(선거 등)": ["거의 하지 않는다 (%)", "월 1~3회 (%)", "주 1~3회 (%)", "주 4~6회 (%)", "매일 한다 (%)"],
    "여가 활동": ["거의 하지 않는다 (%)", "월 1~3회 (%)", "주 1~3회 (%)", "주 4~6회 (%)", "매일 한다 (%)"],
    "저녁 식사": ["거의 하지 않는다 (%)", "월 1~3회 (%)", "주 1~3회 (%)", "주 4~6회 (%)", "매일 한다 (%)"]
}

# 각 특성별로 그래프 생성
for group, x_labels_fixed in categories_groups.items():
    # 해당 그룹에 포함된 열만 추출
    group_columns = [col for col in data.columns if group in col]
    
    # 수치 데이터만 추출
    overall_numeric = overall_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    joson_numeric = joson_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    
    # 그래프 그리기
    x = range(len(x_labels_fixed))
    plt.figure(figsize=(10, 6))
    bar_width = 0.4  # 막대 너비
    plt.bar([i - bar_width / 2 for i in x], overall_numeric, bar_width, label='전체', color='blue')
    plt.bar([i + bar_width / 2 for i in x], joson_numeric, bar_width, label='조손가정', color='orange')
    
    plt.xticks(x, x_labels_fixed, rotation=45, ha='right', fontsize=10)
    plt.xlabel('빈도별 활동')
    plt.ylabel('비율 (%)')
    plt.title(f'{group} 비교')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
file_path = './학교생활_만족도.csv'
data = pd.read_csv(file_path, encoding='cp949')

# "전체"와 "조손가정" 데이터 추출
overall_data = data[data['특성별(2)'].str.contains('소계', na=False)]
joson_data = data[data['특성별(2)'].str.contains('한부모 및 조손가족 등', na=False)]

# 특성 그룹 생성 (6개로 분류)
categories_groups = {
    "나는 수업 시간이 재미있다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ],
    "우리 학교는 우리들의 의견을 잘 반영한다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ],
    "우리 학교는 교칙이 엄격하다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ],
    "선생님 친구 등과의 관계를 고려하면 현재 다니고 있는 학교의 생활이 만족스럽다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ]
}

# 각 특성별로 그래프 생성
for group, x_labels_fixed in categories_groups.items():
    # 해당 그룹에 포함된 열만 추출
    group_columns = [col for col in data.columns if group in col]
    
    # 수치 데이터만 추출
    overall_numeric = overall_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    joson_numeric = joson_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    
    # 그래프 그리기
    x = range(len(x_labels_fixed))
    plt.figure(figsize=(10, 6))
    bar_width = 0.4  # 막대 너비
    plt.bar([i - bar_width / 2 for i in x], overall_numeric, bar_width, label='전체', color='blue')
    plt.bar([i + bar_width / 2 for i in x], joson_numeric, bar_width, label='조손가정', color='orange')
    
    plt.xticks(x, x_labels_fixed, rotation=45, ha='right', fontsize=10)
    plt.xlabel('빈도별 활동')
    plt.ylabel('비율 (%)')
    plt.title(f'{group} 비교')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
achievement_data = pd.read_csv('./학업_성취도.csv', encoding='cp949')

# 그래프 생성
categories = ["매우 못한다 (%)", "못하는 편이다 (%)", "보통이다 (%)", "잘하는 편이다 (%)", "매우 잘한다 (%)", "평균 (점)"]

# 데이터 추출
overall_category = achievement_data.loc[achievement_data['특성별(2)'].str.contains('소계'), categories].iloc[0]
joson_category = achievement_data.loc[achievement_data['특성별(2)'].str.contains('한부모 및 조손가족 등'), categories].iloc[0]

# 그래프 그리기
x_labels = categories
x = range(len(x_labels))
plt.figure(figsize=(10, 6))
bar_width = 0.4  # 막대 너비

plt.bar([i - bar_width / 2 for i in x], overall_category, bar_width, label='전체', color='blue')
plt.bar([i + bar_width / 2 for i in x], joson_category, bar_width, label='조손가정', color='orange')

plt.xticks(x, x_labels, rotation=45, ha='right', fontsize=10)
plt.xlabel('응답 카테고리')
plt.ylabel('비율 (%) / 평균 (점)')
plt.title("전체와 조손가정 간 학업 성취도 비교")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
file_path = './학교생활_만족도.csv'
data = pd.read_csv(file_path, encoding='cp949')

# "전체"와 "조손가정" 데이터 추출
overall_data = data[data['특성별(2)'].str.contains('소계', na=False)]
joson_data = data[data['특성별(2)'].str.contains('한부모 및 조손가족 등', na=False)]

# 특성 그룹 생성 (6개로 분류)
categories_groups = {
    "나는 수업 시간이 재미있다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ],
    "우리 학교는 우리들의 의견을 잘 반영한다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ],
    "우리 학교는 교칙이 엄격하다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ],
    "선생님 친구 등과의 관계를 고려하면 현재 다니고 있는 학교의 생활이 만족스럽다": [
        "전혀 그렇지 않다 (%)",
        "그렇지 않은 편이다 (%)",
        "그런 편이다 (%)",
        "매우 그렇다 (%)",
        "평균 (점)"
    ]
}

# 각 특성별로 그래프 생성
for group, x_labels_fixed in categories_groups.items():
    # 해당 그룹에 포함된 열만 추출
    group_columns = [col for col in data.columns if group in col]
    
    # 수치 데이터만 추출
    overall_numeric = overall_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    joson_numeric = joson_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    
    # 그래프 그리기
    x = range(len(x_labels_fixed))
    plt.figure(figsize=(10, 6))
    bar_width = 0.4  # 막대 너비
    plt.bar([i - bar_width / 2 for i in x], overall_numeric, bar_width, label='전체', color='blue')
    plt.bar([i + bar_width / 2 for i in x], joson_numeric, bar_width, label='조손가정', color='orange')
    
    plt.xticks(x, x_labels_fixed, rotation=45, ha='right', fontsize=10)
    plt.xlabel('빈도별 활동')
    plt.ylabel('비율 (%)')
    plt.title(f'{group} 비교')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
file_path = './우울감__자아존중감.csv'
data = pd.read_csv(file_path, encoding='cp949')
import pandas as pd
import matplotlib.pyplot as plt

# "전체"와 "조손가정" 데이터 추출
overall_data = data[data['특성별(2)'].str.contains('소계', na=False)]
joson_data = data[data['특성별(2)'].str.contains('한부모 및 조손가족 등', na=False)]

# 특성 그룹 생성 (6개로 분류)
categories_groups = {
    "이유 없이 외로운 적이 있다": [
        "전혀 그렇지 않다",
        "그렇지 않은 편이다",
        "그런 편이다",
        "매우 그렇다"
    ],
    "이유 없이 불안한 적이 있다": [
        "전혀 그렇지 않다",
        "그렇지 않은 편이다",
        "그런 편이다",
        "매우 그렇다"
    ],
    "이유 없이 슬프거나 우울한 적이 있다": [
        "전혀 그렇지 않다",
        "그렇지 않은 편이다",
        "그런 편이다",
        "매우 그렇다"
    ],
    "가치 있는 사람이라고 생각한다": [
        "전혀 그렇지 않다",
        "그렇지 않은 편이다",
        "그런 편이다",
        "매우 그렇다"
    ],
    "좋은 자질(장점)을 많이 가지고 있다고 생각한다": [
        "전혀 그렇지 않다",
        "그렇지 않은 편이다",
        "그런 편이다",
        "매우 그렇다"
    ],
    "나 스스로에 대해 자랑스러워할 만한 것이 별로 없다": [
        "전혀 그렇지 않다",
        "그렇지 않은 편이다",
        "그런 편이다",
        "매우 그렇다"
    ]
}

# 각 특성별로 그래프 생성
for group, x_labels_fixed in categories_groups.items():
    # 해당 그룹에 포함된 열만 추출
    group_columns = [col for col in data.columns if group in col]
    
    # 수치 데이터만 추출
    overall_numeric = overall_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    joson_numeric = joson_data[group_columns].apply(pd.to_numeric, errors='coerce').mean()
    
    # 그래프 그리기
    x = range(len(x_labels_fixed))
    plt.figure(figsize=(10, 6))
    bar_width = 0.4  # 막대 너비
    plt.bar([i - bar_width / 2 for i in x], overall_numeric, bar_width, label='전체', color='blue')
    plt.bar([i + bar_width / 2 for i in x], joson_numeric, bar_width, label='조손가정', color='orange')
    
    plt.xticks(x, x_labels_fixed, rotation=45, ha='right', fontsize=10)
    plt.xlabel('빈도별 활동')
    plt.ylabel('비율 (%)')
    plt.title(f'{group} 비교')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '특성별(2)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 11
#       8 import matplotlib.pyplot as plt
#      10 # "전체"와 "조손가정" 데이터 추출
# ---> 11 overall_data = data[data['특성별(2)'].str.contains('소계', na=False)]
#      12 joson_data = data[data['특성별(2)'].str.contains('한부모 및 조손가족 등', na=False)]
#      14 # 특성 그룹 생성 (6개로 분류)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '특성별(2)'
